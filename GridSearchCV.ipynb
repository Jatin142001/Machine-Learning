# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load the dataset.

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Showing the type of species in the species column.

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X = df.drop('species', axis=1)
y = df['species']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

model_KNN = KNeighborsClassifier(n_neighbors=5)

# %%
model_KNN.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
model_KNN.score(X_test,y_test)
# Out:
# 0.98

# %%
from sklearn.svm import SVC

model_svm = SVC(gamma = 'auto')

# %%
model_svm.fit(X_train,y_train)
# Out:
# SVC(gamma='auto')

# %%
model_svm.score(X_test,y_test)
# Out:
# 1.0

# %% [markdown]
# ### Showing how to use Grid Search CV for Support Vector Machine.

# %%
from sklearn.model_selection import GridSearchCV

# %%
classifier = GridSearchCV((model_svm),{
    'C': [1,10,20,30],
    'kernel': ['rbf','linear']
},cv = 5,return_train_score = False)

# %%
classifier.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(gamma='auto'),
#              param_grid={'C': [1, 10, 20, 30], 'kernel': ['rbf', 'linear']})

# %%
result = pd.DataFrame(classifier.cv_results_)

# %%
result
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.002122      0.000672         0.001037        0.000538        1
# 1       0.001388      0.000083         0.001398        0.000077        1
# 2       0.001944      0.000486         0.001458        0.000271       10
# 3       0.001915      0.000473         0.001106        0.000203       10
# 4       0.001966      0.000579         0.001129        0.000164       20
# 5       0.001894      0.000318         0.001120        0.000101       20
# 6       0.002459      0.001927         0.001797        0.000395       30
# 7       0.003251      0.000378         0.001574        0.000788       30
#
#   param_kernel                         params  split0_test_score  \
# 0          rbf      {'C': 1, 'kernel': 'rbf'}           0.966667
# 1       linear   {'C': 1, 'kernel': 'linear'}           0.966667
# 2          rbf     {'C': 10, 'kernel': 'rbf'}           0.966667
# 3       linear  {'C': 10, 'kernel': 'linear'}           1.000000
# 4          rbf     {'C': 20, 'kernel': 'rbf'}           0.966667
# 5       linear  {'C': 20, 'kernel': 'linear'}           1.000000
# 6          rbf     {'C': 30, 'kernel': 'rbf'}           0.966667
# 7       linear  {'C': 30, 'kernel': 'linear'}           1.000000
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0                1.0           0.966667           0.966667                1.0
# 1                1.0           0.966667           0.966667                1.0
# 2                1.0           0.966667           0.966667                1.0
# 3                1.0           0.900000           0.966667                1.0
# 4                1.0           0.900000           0.966667                1.0
# 5                1.0           0.900000           0.933333                1.0
# 6                1.0           0.900000           0.933333                1.0
# 7                1.0           0.900000           0.900000                1.0
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.980000        0.016330                1
# 1         0.980000        0.016330                1
# 2         0.980000        0.016330                1
# 3         0.973333        0.038873                4
# 4         0.966667        0.036515                5
# 5         0.966667        0.042164                6
# 6         0.960000        0.038873                7
# 7         0.960000        0.048990                7

# %%
result[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1          rbf         0.980000
# 1        1       linear         0.980000
# 2       10          rbf         0.980000
# 3       10       linear         0.973333
# 4       20          rbf         0.966667
# 5       20       linear         0.966667
# 6       30          rbf         0.960000
# 7       30       linear         0.960000

# %% [markdown]
# ### Showing how to use Grid Search CV for K-Nearest Neighbors.

# %%
from sklearn.neighbors import KNeighborsClassifier

model_KNN = KNeighborsClassifier(weights='uniform')

# %%
classifier_KNN = GridSearchCV((model_KNN),{
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
    'n_neighbors': [3,5,7,9,11,13,15],
    'leaf_size': [10,20,30]
},cv = 5,return_train_score = False)

# %%
classifier_KNN.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'leaf_size': [10, 20, 30],
#                          'n_neighbors': [3, 5, 7, 9, 11, 13, 15]})

# %%
result_KNN = pd.DataFrame(classifier_KNN.cv_results_)

# %%
result_KNN
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002609      0.000515         0.003839        0.000788
# 1        0.003512      0.000650         0.005586        0.001336
# 2        0.003016      0.000648         0.006184        0.001004
# 3        0.001813      0.000735         0.005209        0.001597
# 4        0.001995      0.000624         0.004200        0.001167
# ..            ...           ...              ...             ...
# 79       0.002207      0.000426         0.008147        0.000662
# 80       0.003610      0.001035         0.014826        0.001115
# 81       0.003488      0.000642         0.011078        0.002480
# 82       0.001608      0.000489         0.007651        0.001586
# 83       0.001601      0.000490         0.006886        0.001097
#
#    param_algorithm  param_leaf_size  param_n_neighbors  \
# 0             auto               10                  3
# 1             auto               10                  5
# 2             auto               10                  7
# 3             auto               10                  9
# 4             auto               10                 11
# ..             ...              ...                ...
# 79           brute               30                  7
# 80           brute               30                  9
# 81           brute               30                 11
# 82           brute               30                 13
# 83           brute               30                 15
#
#                                                params  split0_test_score  \
# 0   {'algorithm': 'auto', 'leaf_size': 10, 'n_neig...           0.966667
# 1   {'algorithm': 'auto', 'leaf_size': 10, 'n_neig...           0.966667
# 2   {'algorithm': 'auto', 'leaf_size': 10, 'n_neig...           0.966667
# 3   {'algorithm': 'auto', 'leaf_size': 10, 'n_neig...           0.966667
# 4   {'algorithm': 'auto', 'leaf_size': 10, 'n_neig...           0.933333
# ..                                                ...                ...
# 79  {'algorithm': 'brute', 'leaf_size': 30, 'n_nei...           0.966667
# 80  {'algorithm': 'brute', 'leaf_size': 30, 'n_nei...           0.966667
# 81  {'algorithm': 'brute', 'leaf_size': 30, 'n_nei...           0.933333
# 82  {'algorithm': 'brute', 'leaf_size': 30, 'n_nei...           0.933333
# 83  {'algorithm': 'brute', 'leaf_size': 30, 'n_nei...           0.933333
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.966667           0.933333           0.966667
# 1            1.000000           0.933333           0.966667
# 2            1.000000           0.966667           0.966667
# 3            1.000000           0.966667           0.933333
# 4            1.000000           1.000000           0.966667
# ..                ...                ...                ...
# 79           1.000000           0.966667           0.966667
# 80           1.000000           0.966667           0.966667
# 81           1.000000           1.000000           0.966667
# 82           1.000000           0.966667           0.966667
# 83           1.000000           0.933333           0.966667
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 1.0         0.966667        0.021082               61
# 1                 1.0         0.973333        0.024944               28
# 2                 1.0         0.980000        0.016330                1
# 3                 1.0         0.973333        0.024944               28
# 4                 1.0         0.980000        0.026667                1
# ..                ...              ...             ...              ...
# 79                1.0         0.980000        0.016330                1
# 80                1.0         0.980000        0.016330                1
# 81                1.0         0.980000        0.026667                1
# 82                1.0         0.973333        0.024944               28
# 83                1.0         0.966667        0.029814               61
#
# [84 rows x 16 columns]

# %%
result_KNN[['mean_test_score', 'rank_test_score']]
# Out:
#     mean_test_score  rank_test_score
# 0          0.966667               61
# 1          0.973333               28
# 2          0.980000                1
# 3          0.973333               28
# 4          0.980000                1
# ..              ...              ...
# 79         0.980000                1
# 80         0.980000                1
# 81         0.980000                1
# 82         0.973333               28
# 83         0.966667               61
#
# [84 rows x 2 columns]

# %% [markdown]
# ### Showing how to use Random Search CV.

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
classifier_random = RandomizedSearchCV((model_KNN),{
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
    'n_neighbors': [3,5,7,9,11,13,15],
    'leaf_size': [10,20,30]
},n_iter = 10,cv = 5,return_train_score = False)

# %%
classifier_random.fit(X,y)
# Out:
# RandomizedSearchCV(cv=5, estimator=KNeighborsClassifier(),
#                    param_distributions={'algorithm': ['auto', 'ball_tree',
#                                                       'kd_tree', 'brute'],
#                                         'leaf_size': [10, 20, 30],
#                                         'n_neighbors': [3, 5, 7, 9, 11, 13,
#                                                         15]})

# %%
result_random = pd.DataFrame(classifier_random.cv_results_)

# %%
result_random
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.002163      0.000678         0.004671        0.001039
# 1       0.002220      0.000835         0.014903        0.017615
# 2       0.001288      0.000411         0.003482        0.000602
# 3       0.002141      0.000861         0.005255        0.001453
# 4       0.002160      0.000597         0.008665        0.001281
# 5       0.003261      0.000698         0.005035        0.000294
# 6       0.001656      0.000837         0.004017        0.000776
# 7       0.002503      0.001594         0.009256        0.001552
# 8       0.001755      0.000746         0.004914        0.001118
# 9       0.003740      0.001779         0.007197        0.001997
#
#    param_n_neighbors  param_leaf_size param_algorithm  \
# 0                  9               20         kd_tree
# 1                  9               20            auto
# 2                  3               10       ball_tree
# 3                  9               30       ball_tree
# 4                 13               10           brute
# 5                  5               20         kd_tree
# 6                 15               20         kd_tree
# 7                  9               30           brute
# 8                  3               30         kd_tree
# 9                  9               30            auto
#
#                                               params  split0_test_score  \
# 0  {'n_neighbors': 9, 'leaf_size': 20, 'algorithm...           0.966667
# 1  {'n_neighbors': 9, 'leaf_size': 20, 'algorithm...           0.966667
# 2  {'n_neighbors': 3, 'leaf_size': 10, 'algorithm...           0.966667
# 3  {'n_neighbors': 9, 'leaf_size': 30, 'algorithm...           0.966667
# 4  {'n_neighbors': 13, 'leaf_size': 10, 'algorith...           0.933333
# 5  {'n_neighbors': 5, 'leaf_size': 20, 'algorithm...           0.966667
# 6  {'n_neighbors': 15, 'leaf_size': 20, 'algorith...           0.933333
# 7  {'n_neighbors': 9, 'leaf_size': 30, 'algorithm...           0.966667
# 8  {'n_neighbors': 3, 'leaf_size': 30, 'algorithm...           0.966667
# 9  {'n_neighbors': 9, 'leaf_size': 30, 'algorithm...           0.966667
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           1.000000           0.966667           0.933333                1.0
# 1           1.000000           0.966667           0.933333                1.0
# 2           0.966667           0.933333           0.966667                1.0
# 3           1.000000           0.966667           0.933333                1.0
# 4           1.000000           0.966667           0.966667                1.0
# 5           1.000000           0.933333           0.966667                1.0
# 6           1.000000           0.933333           0.966667                1.0
# 7           1.000000           0.966667           0.966667                1.0
# 8           0.966667           0.933333           0.966667                1.0
# 9           1.000000           0.966667           0.933333                1.0
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.973333        0.024944                2
# 1         0.973333        0.024944                2
# 2         0.966667        0.021082                8
# 3         0.973333        0.024944                2
# 4         0.973333        0.024944                2
# 5         0.973333        0.024944                2
# 6         0.966667        0.029814                8
# 7         0.980000        0.016330                1
# 8         0.966667        0.021082                8
# 9         0.973333        0.024944                2

# %%
result_random[['params','mean_test_score', 'rank_test_score']]
# Out:
#                                               params  mean_test_score  \
# 0  {'n_neighbors': 9, 'leaf_size': 20, 'algorithm...         0.973333
# 1  {'n_neighbors': 9, 'leaf_size': 20, 'algorithm...         0.973333
# 2  {'n_neighbors': 3, 'leaf_size': 10, 'algorithm...         0.966667
# 3  {'n_neighbors': 9, 'leaf_size': 30, 'algorithm...         0.973333
# 4  {'n_neighbors': 13, 'leaf_size': 10, 'algorith...         0.973333
# 5  {'n_neighbors': 5, 'leaf_size': 20, 'algorithm...         0.973333
# 6  {'n_neighbors': 15, 'leaf_size': 20, 'algorith...         0.966667
# 7  {'n_neighbors': 9, 'leaf_size': 30, 'algorithm...         0.980000
# 8  {'n_neighbors': 3, 'leaf_size': 30, 'algorithm...         0.966667
# 9  {'n_neighbors': 9, 'leaf_size': 30, 'algorithm...         0.973333
#
#    rank_test_score
# 0                2
# 1                2
# 2                8
# 3                2
# 4                2
# 5                2
# 6                8
# 7                1
# 8                8
# 9                2
